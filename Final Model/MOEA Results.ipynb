# %%
### Check convergence and seed analsis with the hyperspace & epsilon progress ###
import pandas as pd
import matplotlib.pyplot as plt
convergence = pd.read_csv('convergence_cluster501.csv')
#convergence = load file here#

fig, (ax1, ax2) = plt.subplots(ncols=2, sharex=True, figsize=(8,4))
ax1.plot(convergence.nfe, convergence.epsilon_progress)
ax1.set_ylabel('$\epsilon$-progress')
ax2.plot(convergence.nfe, convergence.hypervolume)
ax2.set_ylabel('hypervolume')

ax1.set_xlabel('number of function evaluations')
ax2.set_xlabel('number of function evaluations')
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

emadata = pd.read_csv('optimization_results_cluster501.csv', index_col = 0)


sns.pairplot(emadata.iloc[:,5:])

# %%
print(emadata.loc[emadata.iloc[:,5] < -0.88])
# Out:
# Empty DataFrame
# Columns: [c1, c2, r1, r2, w, mean effectiveness, mean time until containment, mean difference in met demand, mean difference in arrival time, mean cost per death prevented]
# Index: []

# %%
import numpy as np

def policy_plotter(c1, c2, r1, r2, w):
    
    result = []
    x_array = np.linspace(0,1,100)
    
    for x in x_array:
        y = min(max(w * abs((x-c1)/r1)**3 + (1-w) * abs((x-c2)/r2)**3,0),1)
        result.append(y)
        
    return result



import matplotlib.pyplot as plt

plt.figure(figsize=(20,20))

selection1 = emadata.loc[emadata.iloc[:,5] < -0.83]

selection2 = emadata.loc[emadata.iloc[:,6] < 14]

selection3 = emadata.loc[emadata.iloc[:,7] < 0.13]

selection4 = emadata.loc[emadata.iloc[:,8] < 450]  

selection5 = emadata.loc[emadata.iloc[:,9] < 2200]

import random
blues = ['#0d5f67', '#0a4c52','#07393d','#052629', '#3d7e85',
        '#6d9fa3', '#9ebfc2', '#cedfe0', '#021314']
browns = ['#7e2e2e', '#642424', '#4b1b1b', '#321212', '#190909',
        '#975757', '#b18181', '#cbabab']
greens = ['#6C9E12', '#567e0e', '#405e0a', '#2b3f07', '#151f03',
         '#89b141', '#a6c470', '#c4d8a0']
purples = ['#69178C', '#541270', '#3f0d54', '#2a0938', '#15041c',
         '#8745a3', '#a573ba', '#c3a2d1']
yellows = ['#DE9733', '#b17828', '#855a1e', '#583c14', '#2c1e0a',
          '#e4ab5b', '#ebc084', '#f1d5ad']

plt.subplot2grid((5,2),(0,1))

for index, row in selection1.iterrows():
    plt.plot(np.linspace(0,1,100), policy_plotter(row['c1'],  row['c2'],  row['r1'],  row['r2'],  row['w']), color=random.choice(greens))
plt.title('Policies with effectivness > 0.83 ($\epsilon$-NSGA2)')

plt.xlabel('Level of Uncertainty in the System')
plt.ylabel('Probability of Choosing an Explorative Action')

plt.subplot2grid((5,2),(1,1))
for index, row in selection2.iterrows():
    plt.plot(np.linspace(0,1,100), policy_plotter(row['c1'],  row['c2'],  row['r1'],  row['r2'],  row['w']), color=random.choice(browns))
plt.title('Policies with containment within 14 weeks ($\epsilon$-NSGA2)')
plt.xlabel('Level of Uncertainty in the System')
plt.ylabel('Probability of Choosing an Explorative Action')

plt.subplot2grid((5,2),(2,1))
for index, row in selection3.iterrows():
    plt.plot(np.linspace(0,1,100), policy_plotter(row['c1'],  row['c2'],  row['r1'],  row['r2'],  row['w']), color=random.choice(blues))
plt.title('Policies with difference in met demand < 0.13 ($\epsilon$-NSGA2)')
plt.xlabel('Level of Uncertainty in the System')
plt.ylabel('Probability of Choosing an Explorative Action')

plt.subplot2grid((5,2),(3,1))
for index, row in selection4.iterrows():
    plt.plot(np.linspace(0,1,100), policy_plotter(row['c1'],  row['c2'],  row['r1'],  row['r2'],  row['w']), color=random.choice(purples))
plt.title('Policies with difference in arrival times < 450 ($\epsilon$-NSGA2)')
plt.xlabel('Level of Uncertainty in the System')
plt.ylabel('Probability of Choosing an Explorative Action')

plt.subplot2grid((5,2),(4,1))
for index, row in selection5.iterrows():
    plt.plot(np.linspace(0,1,100), policy_plotter(row['c1'],  row['c2'],  row['r1'],  row['r2'],  row['w']), color=random.choice(yellows))
plt.title('Policies with cost per death prevented < 2200 ($\epsilon$-NSGA2)')    
plt.xlabel('Level of Uncertainty in the System')
plt.ylabel('Probability of Choosing an Explorative Action')


selection1 = df.loc[df.iloc[:,5] < -0.88]

selection2 = df.loc[df.iloc[:,6] < 6]

selection3 = df.loc[df.iloc[:,7] < 0.04]

selection4 = df.loc[df.iloc[:,8] < 350]  

selection5 = df.loc[df.iloc[:,9] < 1200]

import random
blues = ['#0d5f67', '#0a4c52','#07393d','#052629', '#3d7e85',
        '#6d9fa3', '#9ebfc2', '#cedfe0', '#021314']
browns = ['#7e2e2e', '#642424', '#4b1b1b', '#321212', '#190909',
        '#975757', '#b18181', '#cbabab']
greens = ['#6C9E12', '#567e0e', '#405e0a', '#2b3f07', '#151f03',
         '#89b141', '#a6c470', '#c4d8a0']
purples = ['#69178C', '#541270', '#3f0d54', '#2a0938', '#15041c',
         '#8745a3', '#a573ba', '#c3a2d1']
yellows = ['#DE9733', '#b17828', '#855a1e', '#583c14', '#2c1e0a',
          '#e4ab5b', '#ebc084', '#f1d5ad']

plt.subplot2grid((5,2),(0,0))
for index, row in selection1.iterrows():
    plt.plot(np.linspace(0,1,100), policy_plotter(row['c1'],  row['c2'],  row['r1'],  row['r2'],  row['w']), color=random.choice(greens))
plt.title('Policies with effectivness > 0.88 (Borg)')

plt.xlabel('Level of Uncertainty in the System')
plt.ylabel('Probability of Choosing an Explorative Action')

plt.subplot2grid((5,2),(1,0))
for index, row in selection2.iterrows():
    plt.plot(np.linspace(0,1,100), policy_plotter(row['c1'],  row['c2'],  row['r1'],  row['r2'],  row['w']), color=random.choice(browns))
plt.title('Policies with containment within 6 weeks (Borg)')
plt.xlabel('Level of Uncertainty in the System')
plt.ylabel('Probability of Choosing an Explorative Action')

plt.subplot2grid((5,2),(2,0))
for index, row in selection3.iterrows():
    plt.plot(np.linspace(0,1,100), policy_plotter(row['c1'],  row['c2'],  row['r1'],  row['r2'],  row['w']), color=random.choice(blues))
plt.title('Policies with difference in met demand < 0.04 (Borg)')
plt.xlabel('Level of Uncertainty in the System')
plt.ylabel('Probability of Choosing an Explorative Action')

plt.subplot2grid((5,2),(3,0))
for index, row in selection4.iterrows():
    plt.plot(np.linspace(0,1,100), policy_plotter(row['c1'],  row['c2'],  row['r1'],  row['r2'],  row['w']), color=random.choice(purples))
plt.title('Policies with difference in arrival times < 350 (Borg)')
plt.xlabel('Level of Uncertainty in the System')
plt.ylabel('Probability of Choosing an Explorative Action')

plt.subplot2grid((5,2),(4,0))
for index, row in selection5.iterrows():
    plt.plot(np.linspace(0,1,100), policy_plotter(row['c1'],  row['c2'],  row['r1'],  row['r2'],  row['w']), color=random.choice(yellows))
plt.title('Policies with cost per death prevented < 1200 (Borg)')    
plt.xlabel('Level of Uncertainty in the System')
plt.ylabel('Probability of Choosing an Explorative Action')

plt.tight_layout()
plt.show()

# %% [markdown]
# ### BORG OUTCOMES ###

# %%
import pandas as pd
df = pd.read_csv('archive.txt', sep=' ',names=['c1', 'c2', 'r1', 'r2', 'w', 
                           'Effectiveness', 'Time until containment', 'Difference in Met Demand', 'Difference in Arrival Times', 'Cost per life saved'])

# %%
import seaborn as sns
import matplotlib.pyplot as plt

data = df[['Effectiveness', 'Time until containment', 'Difference in Met Demand', 'Difference in Arrival Times', 'Cost per life saved']]
sns.pairplot(data)
plt.show()

# %%
print(df.loc[df.Effectiveness < -0.88])
# Out:
#            c1        c2        r1        r2         w  Effectiveness  \
# 14   1.000000  0.925993  0.796536  0.808965  0.988780      -0.880781
# 52   0.807098  0.990766  0.203701  0.200858  0.706431      -0.883535
# 67   0.835996  0.457665  0.668660  0.881967  0.208039      -0.885596
# 84   0.334111  0.990720  0.768953  0.661965  0.278203      -0.880145
# 103  0.367163 -0.529278  0.837055  0.662879  0.999526      -0.886342
# 135  0.998701  0.977567  0.761109  0.808965  0.993038      -0.880327
# 148  0.356111  0.476011  0.888042  0.827078  0.851858      -0.881327
# 153  0.394582  0.662612  0.740441  0.421542  0.451335      -0.885062
# 174 -0.037621  0.473800  0.896353  0.831778  0.118670      -0.881200
# 300  0.826295  0.560971  0.216409  0.722373  0.346153      -0.887396
# 363  0.602184  0.540826  0.497133  0.836858  0.699634      -0.881913
# 390  0.960692  0.851394  0.374287  0.139462  0.992082      -0.883009
# 494  0.501270  0.228384  0.871821  0.985834  0.364786      -0.883922
# ...

# %%
print(df.loc[df.Speed < 6])
# Out:
#            c1        c2        r1        r2         w  Effectiveness  Speed  \
# 14   1.000000  0.925993  0.796536  0.808965  0.988780      -0.880781      5
# 28   0.810186  0.645292  0.950473  0.485120  0.607701      -0.864556      5
# 71   1.000000  0.925993  0.796685  0.808965  0.995424      -0.855829      5
# 84   0.334111  0.990720  0.768953  0.661965  0.278203      -0.880145      5
# 103  0.367163 -0.529278  0.837055  0.662879  0.999526      -0.886342      5
# 194  0.363403  0.157035  0.905079  0.492146  1.000000      -0.859120      5
# 227  0.960793  0.758420  0.528099  0.566083  0.655850      -0.862984      5
# 293  0.767644  1.000000  0.827971  0.512045  0.585537      -0.870346      5
# 390  0.960692  0.851394  0.374287  0.139462  0.992082      -0.883009      5
# 398  0.408833  0.397191  0.847579  0.700502  0.661914      -0.865338      5
# 437  0.585103  0.532990  1.000000  0.323132  1.000000      -0.853883      5
# ...

# %%
print(df.loc[df.Equity_MD < 0.04])
# Out:
#            c1        c2        r1        r2         w  Effectiveness  Speed  \
# 141  0.189347  0.297782  0.663825  0.677523  0.470387      -0.751473     25
# 301  0.692481  0.513795  0.706368  0.351235  0.716402      -0.773816     24
# 695  0.305670  0.452870  0.936236  0.252359  0.899461      -0.780148     25
#
#      Equity_MD  Equity_AT   Efficiency
# 141   0.033334   399.4375  3274.813280
# 301   0.035961   447.7500  3312.441251
# 695   0.038334   477.7500  3112.959510

# %%
print(df.loc[df.Equity_AT < 350])
# Out:
#            c1        c2        r1        r2         w  Effectiveness  Speed  \
# 0    0.806047 -0.523705  0.533927  0.230157  0.807454      -0.433845     26
# 185  0.310568  0.006200  0.539050  0.604281  0.624870      -0.724772     20
# 254  0.607472 -0.240962  0.200315  0.239850  0.597984      -0.409463     26
# 379  0.807098 -0.240885  0.208419  0.820189  0.506551      -0.622189     25
# 548  0.074079  0.656525  0.974175  0.049293  0.311307      -0.645049     24
# 557  0.045296 -0.093485  0.158898  0.467732  0.806058      -0.601164     22
# 666 -0.486054 -0.199829  0.756839  0.951710  0.258526      -0.456745     26
# 669  0.400237 -0.391310  0.916817  0.713073  0.354442      -0.461670     26
#
#      Equity_MD  Equity_AT   Efficiency
# 0     0.332457   341.0000  6006.506429
# 185   0.496914   333.0000  3649.627690
# 254   0.331552   325.4375  6398.725755
# 379   0.656561   301.7500  4678.010265
# 548   0.397696   340.0000  4039.832871
# 557   0.397686   321.4375  4421.285794
# ...

# %%
print(df.loc[df.Efficiency < 1200])
# Out:
#            c1        c2        r1        r2         w  Effectiveness  Speed  \
# 71   1.000000  0.925993  0.796685  0.808965  0.995424      -0.855829      5
# 89   0.642676  0.152222  0.646812  0.952731  0.862071      -0.872886      7
# 148  0.356111  0.476011  0.888042  0.827078  0.851858      -0.881327      6
# 329  0.711684  0.553238  0.756526  0.809324  0.251520      -0.867701      6
# 398  0.408833  0.397191  0.847579  0.700502  0.661914      -0.865338      5
# 415  0.633355  0.297782  0.662479  0.774459  0.468613      -0.868590      8
# 445  0.597258  0.406396  0.499912  0.633425  0.824507      -0.821469      8
# 457  0.416032  0.517538  0.908605  0.525646  0.886055      -0.851869      5
# 547  0.586349  0.389513  0.562035  0.658451  0.726648      -0.848457      6
# 661  0.760093  0.356904  0.816285  1.000000  0.661981      -0.851158      6
#
#      Equity_MD  Equity_AT   Efficiency
# 71    0.628617  1393.7500  1058.441809
# 89    0.506137  1387.7500  1185.700928
# ...

# %% [markdown]
# ### Plotting the different policy functions ###

# %%
import numpy as np

def policy_plotter(c1, c2, r1, r2, w):
    
    result = []
    x_array = np.linspace(0,1,100)
    
    for x in x_array:
        y = min(max(w * abs((x-c1)/r1)**3 + (1-w) * abs((x-c2)/r2)**3,0),1)
        result.append(y)
        
    return result



import matplotlib.pyplot as plt

plt.figure(figsize=(10,20))

selection1 = df.loc[df.iloc[:,5] < -0.88]

selection2 = df.loc[df.iloc[:,6] < 6]

selection3 = df.loc[df.iloc[:,7] < 0.04]

selection4 = df.loc[df.iloc[:,8] < 350]  

selection5 = df.loc[df.iloc[:,9] < 1200]

import random
blues = ['#0d5f67', '#0a4c52','#07393d','#052629', '#3d7e85',
        '#6d9fa3', '#9ebfc2', '#cedfe0', '#021314']
browns = ['#7e2e2e', '#642424', '#4b1b1b', '#321212', '#190909',
        '#975757', '#b18181', '#cbabab']
greens = ['#6C9E12', '#567e0e', '#405e0a', '#2b3f07', '#151f03',
         '#89b141', '#a6c470', '#c4d8a0']
purples = ['#69178C', '#541270', '#3f0d54', '#2a0938', '#15041c',
         '#8745a3', '#a573ba', '#c3a2d1']
yellows = ['#DE9733', '#b17828', '#855a1e', '#583c14', '#2c1e0a',
          '#e4ab5b', '#ebc084', '#f1d5ad']

plt.subplot(511)

for index, row in selection1.iterrows():
    plt.plot(np.linspace(0,1,100), policy_plotter(row['c1'],  row['c2'],  row['r1'],  row['r2'],  row['w']), color=random.choice(blues))
plt.title('Policies with effectivness > 0.88')

plt.xlabel('Level of Uncertainty in the System')
plt.ylabel('Probability of Choosing an Explorative Action')

plt.subplot(512)
for index, row in selection2.iterrows():
    plt.plot(np.linspace(0,1,100), policy_plotter(row['c1'],  row['c2'],  row['r1'],  row['r2'],  row['w']), color=random.choice(browns))
plt.title('Policies with containment within 6 weeks')
plt.xlabel('Level of Uncertainty in the System')
plt.ylabel('Probability of Choosing an Explorative Action')

plt.subplot(513)
for index, row in selection3.iterrows():
    plt.plot(np.linspace(0,1,100), policy_plotter(row['c1'],  row['c2'],  row['r1'],  row['r2'],  row['w']), color=random.choice(greens))
plt.title('Policies with difference in met demand < 0.04')
plt.xlabel('Level of Uncertainty in the System')
plt.ylabel('Probability of Choosing an Explorative Action')

plt.subplot(514)
for index, row in selection4.iterrows():
    plt.plot(np.linspace(0,1,100), policy_plotter(row['c1'],  row['c2'],  row['r1'],  row['r2'],  row['w']), color=random.choice(purples))
plt.title('Policies with difference in arrival times < 350')
plt.xlabel('Level of Uncertainty in the System')
plt.ylabel('Probability of Choosing an Explorative Action')

plt.subplot(515)
for index, row in selection5.iterrows():
    plt.plot(np.linspace(0,1,100), policy_plotter(row['c1'],  row['c2'],  row['r1'],  row['r2'],  row['w']), color=random.choice(yellows))
plt.title('Policies with cost per death prevented < 1200')    
plt.xlabel('Level of Uncertainty in the System')
plt.ylabel('Probability of Choosing an Explorative Action')

plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

def policy_plotter(c1, c2, r1, r2, w):
    
    result = []
    x_array = np.linspace(0,1,100)
    
    for x in x_array:
        y = min(max(w * abs((x-c1)/r1)**3 + (1-w) * abs((x-c2)/r2)**3,0),1)
        result.append(y)
        
    return result


plt.plot(np.linspace(0,1,100), policy_plotter(0.189347,  0.297782,  0.663825,  0.677523,  0.470387), color='#0D5F67', linewidth=3.5)
plt.title('Policy 141')    
plt.xlabel('Level of Uncertainty in the System')
plt.ylabel('Probability of Choosing an Explorative Action')

plt.ylim([-0.1,1.1])

plt.tight_layout()
plt.show()

# %%
emadata['algorithm'] = '$\epsilon$-NSGA2'
df['algorithm'] = 'Borg'

df = df.rename(columns={'Cost per life saved': 'Cost per death prevented'})

emadata= emadata.rename(columns={"mean effectiveness": "Effectiveness", 
                        "mean cost per death prevented": "Cost per death prevented",
                        "mean difference in arrival time": "Difference in Arrival Times",
                        "mean difference in met demand": "Difference in Met Demand",
                        "mean time until containment": "Time until containment"})


#have to rename the colums of the emadata
both = df.append(emadata)

both
# Out:
#            c1        c2        r1        r2         w  Effectiveness  \
# 0    0.806047 -0.523705  0.533927  0.230157  0.807454      -0.433845
# 1    0.693578  0.506259  0.660657  0.665312  0.733220      -0.773765
# 2    0.285792  0.478169  0.668713  0.457746  0.794793      -0.771707
# 3    0.396216  0.281037  0.988145  0.985550  0.798529      -0.810595
# 4    0.370691  0.837984  0.524416  0.206636  0.830400      -0.792733
# 5    0.285395  0.334105  0.768690  0.602552  0.280425      -0.804461
# 6    0.286174  0.586657  0.939818  0.700894  0.798529      -0.869570
# 7    0.665053  0.399182  0.756109  0.616905  0.540518      -0.837747
# 8    0.766710  0.937875  0.949376  0.674498  0.567381      -0.865873
# 9    0.671123  0.268575  1.000000  0.794162  0.308372      -0.860828
# 10   0.286174  0.488579  0.636602  0.605342  0.798529      -0.795983
# 11   0.599681  0.231834  0.860444  0.705540  0.753069      -0.861719
# 12   0.286174  0.141994  0.939818  0.688200  0.430777      -0.763817
# ...

# %%
 sns.pairplot(both.iloc[:,5:], hue='algorithm')
