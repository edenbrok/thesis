# %%
import pandas as pd
df = pd.read_csv('archive.txt', sep=' ',names=['c1', 'c2', 'r1', 'r2', 'w', 
                           'Effectiveness', 'Speed', 'Equity in Met Demand', 'Equity in Arrival Times', 'Efficiency'])

print(df[['Effectiveness', 'Speed', 'Equity in Met Demand', 'Equity in Arrival Times', 'Efficiency']])
# Out:
#      Effectiveness  Speed  Equity in Met Demand  Equity in Arrival Times  \
# 0        -0.433845     26              0.332457                 341.0000
# 1        -0.773765     12              0.273662                 725.9375
# 2        -0.771707     18              0.296125                 662.9375
# 3        -0.810595      9              0.422130                1060.4375
# 4        -0.792733     17              0.107734                 470.9375
# 5        -0.804461     13              0.260092                 724.4375
# 6        -0.869570      6              0.415432                1153.7500
# 7        -0.837747     26              0.354091                 854.4375
# 8        -0.865873     26              0.307626                 839.7500
# 9        -0.860828     26              0.241328                 879.4375
# 10       -0.795983     14              0.254229                 794.0000
# 11       -0.861719     26              0.396185                1072.4375
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt

data = df[['Effectiveness', 'Speed', 'Equity in Met Demand', 'Equity in Arrival Times', 'Efficiency']]
sns.pairplot(data)
plt.show()
